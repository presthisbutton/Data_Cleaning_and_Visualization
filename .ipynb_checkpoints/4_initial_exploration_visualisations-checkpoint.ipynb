# %% [markdown]
# # Data visualisation with python
#
# We will start creating simple plots with a simple dataset — the famous "Titanic" survivalship data, which we can directly load using the Seaborn library:

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male 22.00      1      0  7.25        S  Third    man
# 1         1       1  female 38.00      1      0 71.28        C  First  woman
# 2         1       3  female 26.00      0      0  7.92        S  Third  woman
# 3         1       1  female 35.00      1      0 53.10        S  First  woman
# 4         0       3    male 35.00      0      0  8.05        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# The `countplot()` allows you to create bar charts of value counts in a column without having to aggregate the data beforehand:
#
# (Note: the object containing a plot is typically called "ax", hence the name of the variable)

# %%
ax = sns.countplot(x = "class", data = titanic)

# %% [markdown]
# You can quickly change the style of the plot with `set_style()`, and the colors of the bars with the argument `palette`:

# %%
sns.set_style("darkgrid") # try whitegrid, dark, white, and ticks
ax = sns.countplot(x = "class", 
                   data = titanic,
                   palette = "colorblind" # try deep, muted, pastel, bright, dark, and colorblind
                   )

# %% [markdown]
# Find more about configuring aesthetics of seaborn plots here: https://seaborn.pydata.org/tutorial/aesthetics.html
#
# More about color palettes here: https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# The argument `hue` stands for "color", and it allows us to create the same plot across another dimension of the dataframe:

# %%
ax = sns.countplot(x = "class",
                   hue = "sex",
                   data = titanic,
                   palette = "Paired"
                   )

# %% [markdown]
# Using `ax.set()` you can access other aesthetical elements of the plot, for example the axis labels or the "tick" labels:

# %%
ax = sns.countplot(x = "class", 
                   hue = "sex",
                   data = titanic,
                   palette = "Paired"
                   )

ax.set(xlabel = None,
       xticklabels = ["poor", "middle class", "rich"]);

# %% [markdown]
# **Exercise:**
#
# 1. Create a plot that displays, using bars, how many survived or did not survive in the Titanic accident:

# %%
ax2 = sns.countplot(data = titanic, x = "survived")
ax2.set_xticklabels(["Not Survived", "Survived"])
# Out:
# [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')]

# %% [markdown]
# Visualizing the relationship between two numerical variables with a scatterplot is easy using `sns.relplot()`.
#
# Docs here: https://seaborn.pydata.org/tutorial/relational.html

# %%
ax = sns.relplot(x = "age",
                 y = "fare",
                 data = titanic)

# %% [markdown]
# Similarly to `countplot()`, you can add additional variables with other visual elements, such as the color (`hue`) or the `style`:

# %%
ax = sns.relplot(x = "age",
                 y = "fare",
                 hue = "class",
                 style = "class",
                 data = titanic)

# %% [markdown]
# Let's import now the Eniac clean datasets and build some plots with them:

# %%
# do not display the number with scientific notation
pd.options.display.float_format = '{:.2f}'.format

# %%
# import cleaned versions of files

# orderlines_cl.csv
url = 'https://drive.google.com/file/d/1lrSr_vVbXN7QSVSScf68DpWwvCMclK5m/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines = pd.read_csv(path)

# orders_cl.csv
url = 'https://drive.google.com/file/d/1cGjJ9o3vtwjK0Sohyr3YVTccXfnTPijT/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders = pd.read_csv(path)

# brands_cl.csv
url = 'https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands = pd.read_csv(path)

# products_cl.csv
url = 'https://drive.google.com/file/d/1rHC8M-HG13FtVncImXBydgDtIHyCPH0g/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products = pd.read_csv(path)

# %% [markdown]
# Transform to date format the columns from orders and orderlines:

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293743 entries, 0 to 293742
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293743 non-null  int64
#  1   id_order          293743 non-null  int64
#  2   product_id        293743 non-null  int64
#  3   product_quantity  293743 non-null  int64
#  4   sku               293743 non-null  object
#  5   unit_price        293743 non-null  float64
#  6   date              293743 non-null  object
#  7   total_price       293743 non-null  float64
#  8   check_orders      293743 non-null  bool
# dtypes: bool(1), float64(2), int64(4), object(2)
# memory usage: 18.2+ MB

# %%
orders['created_date'] = pd.to_datetime(orders['created_date'])
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %%
products['price'].mean()
# Out:
# 667.3462680144781

# %% [markdown]
# ## Company revenue

# %% [markdown]
# First I will need to filter only the orders that have a completed state:

# %%
orders_compl = orders.query('state == "Completed"')

# %% [markdown]
# Before we create a visualisation, we always need to prepare our dataframe:

# %%
p_df = (
orders_compl
    # create two new columns in our dataframe; year and month
    .assign(year = orders['created_date'].dt.strftime('%Y'), 
           month = orders['created_date'].dt.strftime('%b'))
    # get the total paid by each year and month
    .groupby(['year', 'month'])
    .agg({'total_paid': 'sum'})
    # reset the index to user the column vector in our plot
    .reset_index()
)
p_df
# Out:
#     year month  total_paid
# 0   2017   Apr   486962.21
# 1   2017   Aug   722055.81
# 2   2017   Dec  1897507.75
# 3   2017   Feb   623896.30
# 4   2017   Jan  1191437.34
# 5   2017   Jul  1127172.80
# 6   2017   Jun   690049.94
# 7   2017   Mar   115937.31
# 8   2017   May   646147.86
# 9   2017   Nov  2949487.12
# 10  2017   Oct  1087801.23
# 11  2017   Sep   861186.73
# 12  2018   Feb  1069705.72
# 13  2018   Jan  1960839.27
# 14  2018   Mar   476872.50

# %%
import matplotlib.pyplot as plt

# Create a list with the months sorted from January to December
# It is going to help us sort our columns appropriately
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# define the size of the plot
# using matplotlib (plt), which operates together with seaborn
plt.subplots(figsize = (12, 8))

p = sns.barplot(
    data = p_df, # dataframe we will use to look for the columns information
    x = 'month', # x values on our chart
    y = 'total_paid', # y values on our chart
    hue = 'year', # group color in our chart
    order = months # order x columns
)

# %% [markdown]
# Once we have the main plot, in this case `p`, we can add additional elements to it. For example, a horizontal line (using `axhline`).
#
# We can also use `plt` to define other elements of the plot such as the title, the labels of the axis or the style:

# %%
# our main plot
plt.subplots(figsize = (12, 8))

p = sns.barplot(
    data = p_df, # dataframe we will use to look for the columns information
    x = 'month', # x values on our chart
    y = 'total_paid', # y values on our chart
    hue = 'year', # group color in our chart
    order = months # order x columns
)

# add a horizontal reference line into the chart to know where the mean value will be
p.axhline(
    p_df['total_paid'].mean(), # value where you want to add your reference line
    linestyle = '--', # type of line you would like to see on the plot. You can find more informaiton on its documentation
    color = 'gray'
)

plt.xlabel('Month') # x label name
plt.ylabel('Total paid') # y label name
plt.title('Total paid evolution through 2017 and 2018') # title
plt.ticklabel_format(style = 'plain', axis = 'y') # remove scientific notation for the y axis
plt.show() # show the plot

# %% [markdown]
# ### Revenue distribution by order id

# %% [markdown]
# I would like to know more about the different values of `total_paid` for each order by month.
#
# Let's talk more about this concept:

# %%
p_df = (
orders_compl
    # create year and month
    .assign(year = orders['created_date'].dt.strftime('%Y'), 
           month = orders['created_date'].dt.strftime('%b'))
)
p_df
# Out:
#         order_id        created_date  total_paid      state  check_orders  \
# 1         241423 2017-11-06 13:10:02      136.15  Completed          True
# 2         242832 2017-12-31 17:40:03       15.76  Completed          True
# 3         243330 2017-02-16 10:59:38       84.98  Completed          True
# 5         245275 2017-06-28 11:35:37      149.00  Completed          True
# 6         245595 2017-01-21 12:52:47      112.97  Completed          True
# ...          ...                 ...         ...        ...           ...
# 204403    527042 2018-03-14 11:47:50       18.98  Completed          True
# 204423    527070 2018-03-14 11:50:48       24.97  Completed          True
# 204426    527074 2018-03-14 11:51:42       24.97  Completed          True
# 204444    527096 2018-03-14 11:58:40       34.96  Completed          True
# 204456    527112 2018-03-14 12:03:52       14.98  Completed          True
#
#         year month
# 1       2017   Nov
# 2       2017   Dec
# 3       2017   Feb
# 5       2017   Jun
# 6       2017   Jan
# ...      ...   ...
# 204403  2018   Mar
# 204423  2018   Mar
# 204426  2018   Mar
# 204444  2018   Mar
# 204456  2018   Mar
#
# [46560 rows x 7 columns]

# %% [markdown]
# If we create a barplot directly:

# %%
plt.subplots(figsize = (12, 8))

sns.barplot(data = p_df, x = 'month', y = 'total_paid', hue = 'year', order = months)

plt.xlabel('Month')
plt.ylabel('Total paid') #default aggregate in Seaborn is the mean
plt.title('Total paid evolution through 2017 and 2018')
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %% [markdown]
# Look at the description of `?sns.barplot` to undersand more about the chart. What's the meaning of the dark lines on top of each bar?

# %% [markdown]
# A better way to see the distribution by month would be to use another type of chart; the boxplot.

# %%
plt.subplots(figsize = (12, 8))

sns.boxplot(data = p_df, 
            x = 'month', 
            y = 'total_paid', 
            hue = 'year', 
            order = months)

plt.ylim(0, 800) # define a limit to put focus on your chart
plt.xlabel('Month')
plt.ylabel('Total paid')
plt.title('Total paid evolution through 2017 and 2018')
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %% [markdown]
# What are we seeing on this chart? Well, the [boxplot](https://en.wikipedia.org/wiki/Box_plot) is a representaition of the pandas function `.describe()`. It shows the main descriptive statistics of a distribution.

# %%
(
p_df
    # select this 3 columns
    .filter(['year','month','total_paid'])
    # apply the describe function to this two groups
    .groupby(['year','month'])
    .describe()
)
# Out:
#            total_paid
#                 count   mean     std  min   25%    50%    75%      max
# year month
# 2017 Apr      1632.00 298.38  614.30 4.99 49.99  89.99 262.98  9423.90
#      Aug      2350.00 307.26  599.39 7.78 51.10 109.99 317.23 10586.97
#      Dec      5506.00 344.63  585.87 6.98 49.98 119.98 362.97  6657.46
#      Feb      2273.00 274.48  520.73 3.99 42.98  94.97 254.98  4163.98
#      Jan      5111.00 233.11  522.33 0.00 37.93  72.96 174.98  7230.97
#      Jul      3438.00 327.86  602.56 7.48 44.98 110.97 365.99  7216.77
#      Jun      1603.00 430.47  752.93 8.89 54.98 137.98 419.98  6698.00
#      Mar       202.00 573.95 1208.63 2.82 39.99 106.98 326.74  9987.76
#      May      1892.00 341.52  594.72 8.98 56.25 115.00 318.96  5335.00
#      Nov      7187.00 410.39  683.62 6.53 71.48 161.23 418.98 13387.78
#      Oct      3135.00 346.99  610.90 6.98 49.98 122.24 344.07  6227.77
#      Sep      2180.00 395.04  682.26 6.98 52.20 131.78 380.38  7376.58
# 2018 Feb      3334.00 320.85  587.50 6.98 49.98 113.97 292.98  6034.97
#      Jan      5202.00 376.94  665.62 6.48 53.99 112.97 362.99  7268.58
#      Mar      1515.00 314.77  633.07 6.98 44.98  96.98 258.04  6656.98

# %% [markdown]
# As you can see, most of our transactions have monthly median values around 100, but maximum values go up to 10,000 and the standard deviation is huge. So we have very different types of customers.
#
# A possible hypothesis is that we have a large group of low-paying customers who are end-users and a small group of 'whale' customers who are companies. What's your hypothesis?

# %% [markdown]
# ### Revenue: zoom in January

# %% [markdown]
# We can zoom into the distribution of one month by filtering one month in our dataset:

# %%
p_df_jan = p_df.query('month == "Jan"')

# %%
plt.subplots(figsize = (18, 10))

sns.histplot(data = p_df_jan, x = 'total_paid', hue = 'year', 
             alpha = .4, # add transparency to you chart
             kde = True, # add a density line in the histogram
             bins = 200 # define the number of bins the variable total paid will be grouped
            )
sns.set_style("white")

plt.xlim(0, 1800)
plt.title('Comparing the distributions of total paid between Jan 2017/18')
plt.xlabel('Total paid')
sns.despine() # remove the top and right margin, to make your plot prettier 
sns.set_style("white")

# %% [markdown]
# Looking at these distributions, we can see that in 2017 there were more orders with a smaller `total_paid`, while in 2018 we observe several spikes between 1000 and 1500, indicating that there were more expensive orders.
#
# Let's check this hypothesis:

# %%
p_df_jan.groupby('year').agg({'total_paid': ['mean', 'median', 'std']})
# Out:
#      total_paid
#            mean median    std
# year
# 2017     233.11  72.96 522.33
# 2018     376.94 112.97 665.62

# %% [markdown]
# My theory is confirmed when we aggregate the data. The standard deviation for 2018 also shows us that there is a higher dispersion compared to 2017, caused mainly by these orders around 1250 euros.
#
# Let's see if we can zoom in into the products information for January.

# %%
# we already have the completed orders for January of both years in our p_df_jan, 
# let's locate them on the orderlines dataset:

p_sku_jan = (
orderlines
    .loc[orderlines['id_order'].isin(p_df_jan['order_id'])] # filter all the orders id in orderlines for month of january (2017 and 2018)
    .assign(year = orderlines['date'].dt.strftime('%Y')) # create year column
    .groupby(['year', 'sku']) # group by year and sku
    .agg({'unit_price': 'sum'}) # aggregate using the sum of the "unit price"
    .reset_index() # reset index so "year" and "sku" become columns
    .sort_values('unit_price', ascending = False) # order by "unit price" to get top products
    .groupby('year') # group by year because we want the top products for each year
    .head(10) # get the first 10 products for each year
)
p_sku_jan
# Out:
#       year      sku  unit_price
# 2370  2018  APP2490    57099.45
# 2371  2018  APP2491    50301.34
# 2255  2018  APP2074    50154.26
# 2369  2018  APP2489    45337.70
# 2373  2018  APP2492    38541.00
# 2425  2018  APP2637    35826.00
# 3456  2018  PAC2119    25979.77
# 2256  2018  APP2075    23829.55
# 1323  2017  PAC1240    21966.00
# 3463  2018  PAC2136    20970.90
# 855   2017  LGE0044    20341.65
# 3454  2018  PAC2115    17588.95
# 231   2017  APP1810    17399.89
# 262   2017  APP1940    12564.93
# 1299  2017  PAC1035    12043.96
# 236   2017  APP1818    11939.96
# 250   2017  APP1876    11644.97
# 1854  2017  WAC0090    10183.36
# 858   2017  LGE0047     8819.93
# 1296  2017  PAC0963     8366.97

# %% [markdown]
# We can now merge these top 10 products from each year (coming from orderlines) with the products dataset, so that we can obtain the names of those products:

# %%
p_sku_jan = p_sku_jan.merge(products, how = 'left')
p_sku_jan
# Out:
#     year      sku  unit_price  \
# 0   2018  APP2490    57099.45
# 1   2018  APP2491    50301.34
# 2   2018  APP2074    50154.26
# 3   2018  APP2489    45337.70
# 4   2018  APP2492    38541.00
# 5   2018  APP2637    35826.00
# 6   2018  PAC2119    25979.77
# 7   2018  APP2075    23829.55
# 8   2017  PAC1240    21966.00
# 9   2018  PAC2136    20970.90
# 10  2017  LGE0044    20341.65
# 11  2018  PAC2115    17588.95
# 12  2017  APP1810    17399.89
# 13  2017  APP1940    12564.93
# 14  2017  PAC1035    12043.96
# 15  2017  APP1818    11939.96
# 16  2017  APP1876    11644.97
# 17  2017  WAC0090    10183.36
# 18  2017  LGE0047     8819.93
# 19  2017  PAC0963     8366.97
#
#                                                  name  \
# 0                          Apple iPhone 64GB X Silver
# 1                     Apple iPhone X 256GB Space Gray
# 2   Apple MacBook Pro 15 "Core i7 Touch Bar 28GHz ...
# 3                      Apple iPhone 64GB Space Gray X
# 4                         Apple iPhone X 256GB Silver
# 5   Apple iMac Pro 27 "8-core Intel Xeon W 32GHz |...
# 6   Apple iMac 27 "Core i7 Retina 5K 42GHz | 32GB ...
# 7   Apple MacBook Pro 15 "Core i7 Touch Bar 29Ghz ...
# 8   Apple MacBook Pro 133 "i5 25GHz | RAM 16GB | 5...
# 9   Apple iMac 27 "Core i5 Retina 5K 34GHz | 16GB ...
# 10       LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C
# 11  Apple iMac 27 "Core i7 Retina 5K 42GHz | 64GB ...
# 12  Apple MacBook Pro 13 "Core i5 2GHz | 8GB RAM |...
# 13  Apple MacBook Pro Retina 13 "i5 27 Ghz | RAM 1...
# 14  Apple iMac 27 "Core i7 Retina 5K 4GHz | 32GB |...
# 15  Apple MacBook Pro 15 "Core i7 Touch Bar 27GHz ...
# 16  Apple MacBook Pro 15 "Core i7 Touch Bar 29GHz ...
# 17           Wacom Cintiq 13HD Graphic Tablet 13 "LED
# 18       LG 38UC99-W Monitor 38 "UHD 4K USB 3.0 USB-C
# 19  Apple iMac 27 "Core i7 Retina 5K 4GHz | 32GB |...
#
#                                                  desc   price       type  \
# 0                 New Apple iPhone 64GB Free Silver X     NaN  113271716
# 1            New Apple iPhone X 256GB Free Space Gray     NaN  113271716
# 2   New MacBook Pro 15-inch Touch Bar to 28GHz Cor... 2805.59   1,02E+12
# 3                              New Free iPhone 64GB X 1159.00  113271716
# 4                New Apple iPhone X 256GB Silver Free     NaN  113271716
# 5   Pro iMac 27 inch screen Retina 5K and Intel Xe... 5499.00  118692158
# 6   IMac desktop computer 27 inch Retina 5K RAM 32... 3799.00   5,74E+15
# 7   New MacBook Pro 15-inch Core i7 Touch Bar 29Gh... 3305.59   1,02E+12
# 8   Apple MacBook Pro 133 inches (MD101Y / A) with... 1899.00       1282
# 9   IMac desktop computer 27 inch 5K Retina 16GB (... 2339.00   5,74E+15
# 10  99% Professional Monitor sRGB color calibrator...  599.00       1296
# 11  IMac desktop computer 27 inch 5K Retina 64GB R... 4639.00   5,74E+15
# 12  MacBook Pro 13 inch i5 2GHz with 8GB RAM and 2... 1699.00       2158
# 13  MacBook Pro 13-inch Retina display 27 Ghz i5 |... 1924.00       1282
# 14  IMac desktop computer 27 inch 5K Retina 4GHz i... 3649.00   5,74E+15
# 15  New MacBook Pro 15-inch Touch Bar to 27GHz Cor... 3199.00       2158
# 16  New MacBook Pro 15-inch Core i7 Touch Bar 29Gh... 4039.00       2158
# 17  Graphics Tablet 13-inch LED HD display with 20...  899.99       1405
# 18  Monitor curved 38 inch IPS 4K ultra high defin... 1299.00       1296
# 19  IMac desktop computer 27 inch 5K Retina 4GHz i... 3409.00   5,74E+15
#
#     max_price_orderlines
# 0                1159.00
# 1                1329.00
# 2                    NaN
# 3                    NaN
# 4                1329.00
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN

# %% [markdown]
# Time to visualize the products:

# %%
# data for 2017
year = "2017"
data_2017 = p_sku_jan.loc[p_sku_jan['year'] == year]

# plot for 2017
sns.barplot(data = data_2017, 
            x = 'unit_price', 
            y = 'name',
            color = 'dodgerblue')

plt.title('Top 10 products for Jan ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %%
# data for 2018
year = "2018"
data_2018 = p_sku_jan.loc[p_sku_jan['year'] == year]

# plot for 2018
sns.barplot(data = data_2018, 
            x = 'unit_price', 
            y = 'name',
            color = 'dodgerblue')

plt.title('Top 10 products for Jan ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %% [markdown]
# Whenever you repeat a task in python with minimal changes, there's usually a way to do it with a loop. You don't need to understand the code below, but feel free to scrutinize it:

# %%
for year in ['2017', '2018']:
    temp = p_sku_jan.loc[p_sku_jan['year'] == year]
    sns.barplot(data = temp, x = 'unit_price', y = 'name', color = 'dodgerblue')
    plt.title('Top 10 products for Jan ' + year)
    plt.xlabel('Total generated income')
    plt.show()

# %% [markdown]
# The [product mix](https://en.wikipedia.org/wiki/Marketing_mix) of the company has changed across the two years.

# %% [markdown]
# ## **CHALLENGES**

# %% [markdown]
# Answer the following questions with the chart you consider most suitable:
#
# 1. Only a fraction of the total number of orders end up being completed. Let's call this fraction (Completed orders / Total number of orders) 'Orders Conversion Rate'. Can you plot the weekly evolution of the 'Orders Conversion Rate'? Find the best chart to represent it.
#
# HINT: Trends throughout time are best represented by lines. Search how to do line plots with Seaborn.

# %%
# orders_conversion = orders.assign(year = orders["created_date"].dt.strftime("%Y"), week = orders["created_date"].dt.strftime("%W"))
# state17 = orders_conversion[orders_conversion.year == "2017"].groupby(["week", "state"]).agg({"state": "count"}).sort_values("week")
# idx1 = pd.IndexSlice
# complete17 = state17.loc[idx1[:, "Completed"], :]["state"].to_list()
# week17 = orders_conversion[orders_conversion.year == "2017"].groupby(["week"]).agg({"state": "count"}).reset_index()
# total17 = week17["state"].to_list()
# week = list(range(0,53))
# rate17 = pd.DataFrame({"year": 2017, "week": week, "completed": complete17, "total": total17})
# rate17["conversion_rate"] = rate17["completed"] / rate17["total"] * 100
# sns.lineplot(data = rate17, x = "week",  y = "conversion_rate", marker = "o")

# %%
# state18 = orders_conversion[orders_conversion.year == "2018"].groupby(["week", "state"]).agg({"state": "count"}).sort_values("week")
# idx2 = pd.IndexSlice
# complete18 = state18.loc[idx2[:, "Completed"], :]["state"].to_list()
# week18 = orders_conversion[orders_conversion.year == "2018"].groupby(["week"]).agg({"state": "count"}).reset_index()
# total18 = week18["state"].to_list()
# week2 = list(range(0,11))
# rate18 = pd.DataFrame({"year": 2018, "week": week2, "completed": complete18, "total": total18})
# rate18["conversion_rate"] = rate18["completed"] / rate18["total"] * 100
# sns.lineplot(data = rate18, x = "week",  y = "conversion_rate", marker = "o")

# %%
# conversion = pd.concat([rate17, rate18], ignore_index = True)
# plt.subplots(figsize = (10, 6))
# weeks = list(range(0, 53, 4))
# ax1 = sns.lineplot(data = conversion, x = "week",  y = "conversion_rate", hue = "year", palette = "Set2", marker = "o");
# sns.despine();
# ax1.set_xticks(weeks);
# plt.title("Weekly Orders Conversion Rate");
# plt.ylabel("conversion rate in %");

# %%
orders_copy = orders.assign(year = orders["created_date"].dt.strftime("%Y"), week = orders["created_date"].dt.strftime("%W"))
conversion_df = orders_conversion.groupby(["year", "week"])["state"].count().reset_index()
conversion_df.rename(columns = {"state": "total"}, inplace = True)
conversion_df["completed"] = orders_conversion[orders_conversion.state == "Completed"].groupby(["year", "week"])["state"].count().reset_index()["state"]
conversion_df["conversion_rate"] = conversion_df["completed"] / conversion_df["total"] * 100
conversion_df.head()
plt.subplots(figsize = (10, 6))
weeks = list(range(0, 53, 4))
ax1 = sns.lineplot(data = conversion_df, x = "week",  y = "conversion_rate", hue = "year", palette = "Set2", marker = "o");
sns.despine();
ax1.set_xticks(weeks);
plt.title("Weekly Orders Conversion Rate");
plt.ylabel("conversion rate in %");

# %%
# From Jose
# plt.subplots(figsize=(16, 8))

# orders = orders.assign(
#     year  = orders['created_date'].dt.strftime('%Y'),
#     month = orders['created_date'].dt.strftime('%b'),
#     week  = orders['created_date'].dt.strftime('%U'),)

# total_orders=orders[['state','year','week']].groupby(['year','week']).count()
# orders_compl=orders[['state','year','week']].query('state == "Completed"').groupby(['year','week']).count()
# orders_conversion_rate = orders_compl/total_orders

# p=sns.lineplot(
#     data= orders_conversion_rate, 
#     x='week', 
#     y='state',
#     hue='year',
#     palette='Blues')

# plt.ylabel('OCR') 
# plt.title('Orders Conversion Rate (OCR) per Week');

# %% [markdown]
# If you combine the unit prices from the products dataframe with the unit price in orderlines, you can find if a discount has been applied into a product and how much is the difference. Find out which are the best visualisation to:
#
# 2. Show the evolution of the average discount (in %) by each month

# %%
discount = orderlines.merge(products, how = "inner")
discount.drop(["id", "id_order", "product_id", "product_quantity", "total_price", "check_orders", "type", "desc", "max_price_orderlines"], axis = 1, inplace = True)
discount.dropna(axis = 0, inplace = True)
#discount = discount.assign(year = discount["date"].dt.strftime("%Y"), month = discount["date"].dt.strftime("%b"))
discount = discount.assign(year_month = discount["date"].dt.to_period(freq = "M"))
discount["discount_rate"] = (discount["price"] - discount["unit_price"]) / discount["price"] * 100
discount["discount_abs"] = discount["price"] - discount["unit_price"]
discount_agg = discount.groupby(["year_month"]).agg({"discount_rate": "mean"}).reset_index()
discount_agg.head()
# Out:
#   year_month  discount_rate
# 0    2017-01          21.18
# 1    2017-02          16.92
# 2    2017-03           7.91
# 3    2017-04          15.34
# 4    2017-05          14.95

# %%
# months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
fig1, ax1 = plt.subplots(figsize = (10, 6))
plt.plot_date(data = discount_agg, x = "year_month", y = "discount_rate", linestyle = "--")
sns.despine();
ax1.set_xticklabels(["2017-2", "2017-4", "2017-6", "2017-8", "2017-10", "2017-12", "2018-2"]);
plt.title("Monthly Average Discount Rate for All Products");
plt.ylabel("discount rate in %");
# Out:
# /var/folders/l7/1vvcr1f15s9dpkc1xqbr10gc0000gn/T/ipykernel_66059/1640241982.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(["2017-2", "2017-4", "2017-6", "2017-8", "2017-10", "2017-12", "2018-2"]);

# %% [markdown]
# 3. Show the top 30 products with the highest discounts in absolute values, on average.

# %%
top30 = discount.sort_values("discount_abs", ascending = False).head(30)
plt.subplots(figsize = (12, 6))
sns.barplot(data = top30, x = "discount_abs", y = "name");
sns.despine();
plt.title("Top 30 Products with Higheset Discounts");
plt.xlabel("discount (Euros)");
plt.ylabel(None);

# %% [markdown]
# 4. Show the distributions of discounts for each brand. Choose the discount measure you consider better to compare all brands. HINT: you can use the first 3 characters of the sku name to merge it with the brands table.

# %%
discount_brand.head()
# Out:
#        sku  unit_price                date  \
# 0  OTT0133       18.99 2017-01-01 00:07:19
# 1  OTT0133       18.99 2017-01-01 10:18:53
# 2  OTT0133       19.99 2017-01-02 16:51:26
# 3  OTT0133       19.99 2017-01-03 11:21:52
# 4  OTT0133       19.99 2017-01-04 10:11:45
#
#                                                 name  price year_month  \
# 0  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...  34.99    2017-01
# 1  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...  34.99    2017-01
# 2  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...  34.99    2017-01
# 3  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...  34.99    2017-01
# 4  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...  34.99    2017-01
#
#    discount_rate  discount_abs sku_short short      long
# 0          45.73         16.00       OTT   OTT  Otterbox
# 1          45.73         16.00       OTT   OTT  Otterbox
# 2          42.87         15.00       OTT   OTT  Otterbox
# 3          42.87         15.00       OTT   OTT  Otterbox
# 4          42.87         15.00       OTT   OTT  Otterbox

# %%
discount["sku_short"] = discount.sku.apply(lambda x: x[0:3])
discount_brand = discount.merge(brands, how = "inner", left_on = "sku_short", right_on = "short")
discount_brand = discount_brand[discount_brand.discount_rate > 0]
discount_brand.groupby("long").agg({"discount_rate": "mean"}).sort_values("discount_rate").reset_index()
plt.subplots(figsize = (15, 50));
sns.boxplot(data = discount_brand, x = "discount_rate", y = "long");
sns.despine();
plt.xlim([0, 100]);
plt.title("Discount Distribution for All Brands");
plt.xlabel("discount rate");
plt.ylabel(None);

# %%
plt.subplots(figsize = (20, 50));
sns.barplot(data = discount_brand, x = "discount_rate", y = "long");
sns.despine();
plt.title("Discount for All Brands");
plt.xlabel("discount rate in %");
plt.ylabel(None);
